# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from piemd import PIEMD
from base_classes import Source, DiskSource
import scipy as sp
from PIL import Image

# %%
image = Image.open("figures_in/g1.jpeg")
img = np.array(image)

src1 = Source(img)
df1 = PIEMD(src1, theta_E=1000, s=100, lens_colour=[1,0,0])
df1.pad_source(1000)

df1.plot_image(lens=False)
df1.plot_image(lens=True)
