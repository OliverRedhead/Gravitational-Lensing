# %%
from deflector import Deflector
import matplotlib.pyplot as plt
import numpy as np

# %%
file = '../Meneghetti_Examples/mass_distributions/kappa.01.017.fits'

# %%
df = Deflector(file,pad=True)

# %%
plt.imshow(df.image(), origin='lower')
plt.show()

# %%
ax,ay = df.deflection_map()

cbar=plt.imshow(ax, origin='lower', cmap='plasma')
plt.colorbar(cbar)
plt.show()
