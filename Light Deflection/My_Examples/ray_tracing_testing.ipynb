# %% [markdown]
# Testing my own implementation of the Ray-Tracing Algorithm.

# %%
from ray_tracing import Plane, Lens, RayTracer

# %%
p = Plane(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p = Plane(data)
#
# NameError: name 'data' is not defined
